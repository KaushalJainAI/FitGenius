# %% [markdown]
# # Report and PPT Visualization Generator
#
# This notebook regenerates all images needed for the FitGenius report or classroom presentation. The images are saved in `notebooks/evaluation_assets` as high-resolution PNG files.

# %% [markdown]
# ## Generate Assets
#
# Run the cell below. It creates charts for algorithm comparison, safety, diversity, novelty, confusion matrix, similarity confidence, and test profile distribution.

# %%
# %run create_evaluation_assets.py

# %% [markdown]
# ## Preview Generated Images

# %%
from pathlib import Path
from IPython.display import Image, display

asset_dir = Path('evaluation_assets')
for image_path in sorted(asset_dir.glob('*.png')):
    print(image_path.name)
    display(Image(filename=str(image_path), width=780))

# %% [markdown]
# ## Suggested Figure Captions
#
# 1. `01_algorithm_metric_comparison.png`: Comparison of rule-based, KNN/content-based, and hybrid recommendation models using accuracy, precision, recall, and F1-score.
# 2. `02_safety_pass_rate.png`: Medical safety pass rate showing whether generated plans respect health constraints.
# 3. `03_diversity_novelty.png`: Diversity and novelty of generated plans, demonstrating variety beyond repeated templates.
# 4. `04_goal_confusion_matrix.png`: Confusion matrix comparing expected fitness goals with recommended goals.
# 5. `05_similarity_confidence.png`: Average cosine similarity of similar profiles used by the hybrid recommender.
# 6. `06_test_profile_distribution.png`: Distribution of test profiles across goal categories.
